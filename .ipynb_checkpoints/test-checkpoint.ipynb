# %%
from nltk.corpus import names
from nltk.classify import apply_features
import random

# %%
def gender_features(name):
    features = {}
    features["last_letter"] = name[-1].lower()
    return features
def gender_features2(name):
    features = {}
    features["first_letter"] = name[0].lower()
    features["suffix1"] = name[-1].lower()
    features["suffix2"] = name[-2:].lower()
    features["len"] = len(name)
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features["count({})".format(letter)] = name.lower().count(letter)
        features["has({})".format(letter)] = (letter in name.lower())
    return features

# %%
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])
random.shuffle(labeled_names)
print(labeled_names[:10])
print()

train_names = labeled_names[1500:]
devtest_names = labeled_names[500:1500]
test_names = labeled_names[:500]
# Out:
# [('Gretchen', 'male'), ('Catherin', 'female'), ('Jean', 'female'), ('Helen', 'female'), ('Cappella', 'female'), ('Brewer', 'male'), ('Dulce', 'female'), ('Petra', 'female'), ('Gardener', 'male'), ('Garv', 'male')]

# %%
featuresets = [(gender_features2(n), gender) for (n, gender) in labeled_names]
print(featuresets[:3])
print()
# Out:
# [({'first_letter': 'g', 'suffix1': 'n', 'suffix2': 'en', 'len': 8, 'count(a)': 0, 'has(a)': False, 'count(b)': 0, 'has(b)': False, 'count(c)': 1, 'has(c)': True, 'count(d)': 0, 'has(d)': False, 'count(e)': 2, 'has(e)': True, 'count(f)': 0, 'has(f)': False, 'count(g)': 1, 'has(g)': True, 'count(h)': 1, 'has(h)': True, 'count(i)': 0, 'has(i)': False, 'count(j)': 0, 'has(j)': False, 'count(k)': 0, 'has(k)': False, 'count(l)': 0, 'has(l)': False, 'count(m)': 0, 'has(m)': False, 'count(n)': 1, 'has(n)': True, 'count(o)': 0, 'has(o)': False, 'count(p)': 0, 'has(p)': False, 'count(q)': 0, 'has(q)': False, 'count(r)': 1, 'has(r)': True, 'count(s)': 0, 'has(s)': False, 'count(t)': 1, 'has(t)': True, 'count(u)': 0, 'has(u)': False, 'count(v)': 0, 'has(v)': False, 'count(w)': 0, 'has(w)': False, 'count(x)': 0, 'has(x)': False, 'count(y)': 0, 'has(y)': False, 'count(z)': 0, 'has(z)': False}, 'male'), ({'first_letter': 'c', 'suffix1': 'n', 'suffix2': 'in', 'len': 8, 'count(a)': 1, 'has(a)': True, 'count(b)': 0, 'has(b)': False, 'count(c)': 1, 'has(c)': True, 'count(d)': 0, 'has(d)': False, 'count(e)': 1, 'has(e)': True, 'count(f)': 0, 'has(f)': False, 'count(g)': 0, 'has(g)': False, 'count(h)': 1, 'has(h)': True, 'count(i)': 1, 'has(i)': True, 'count(j)': 0, 'has(j)': False, 'count(k)': 0, 'has(k)': False, 'count(l)': 0, 'has(l)': False, 'count(m)': 0, 'has(m)': False, 'count(n)': 1, 'has(n)': True, 'count(o)': 0, 'has(o)': False, 'count(p)': 0, 'has(p)': False, 'count(q)': 0, 'has(q)': False, 'count(r)': 1, 'has(r)': True, 'count(s)': 0, 'has(s)': False, 'count(t)': 1, 'has(t)': True, 'count(u)': 0, 'has(u)': False, 'count(v)': 0, 'has(v)': False, 'count(w)': 0, 'has(w)': False, 'count(x)': 0, 'has(x)': False, 'count(y)': 0, 'has(y)': False, 'count(z)': 0, 'has(z)': False}, 'female'), ({'first_letter': 'j', 'suffix1': 'n', 'suffix2': 'an', 'len': 4, 'count(a)': 1, 'has(a)': True, 'count(b)': 0, 'has(b)': False, 'count(c)': 0, 'has(c)': False, 'count(d)': 0, 'has(d)': False, 'count(e)': 1, 'has(e)': True, 'count(f)': 0, 'has(f)': False, 'count(g)': 0, 'has(g)': False, 'count(h)': 0, 'has(h)': False, 'count(i)': 0, 'has(i)': False, 'count(j)': 1, 'has(j)': True, 'count(k)': 0, 'has(k)': False, 'count(l)': 0, 'has(l)': False, 'count(m)': 0, 'has(m)': False, 'count(n)': 1, 'has(n)': True, 'count(o)': 0, 'has(o)': False, 'count(p)': 0, 'has(p)': False, 'count(q)': 0, 'has(q)': False, 'count(r)': 0, 'has(r)': False, 'count(s)': 0, 'has(s)': False, 'count(t)': 0, 'has(t)': False, 'count(u)': 0, 'has(u)': False, 'count(v)': 0, 'has(v)': False, 'count(w)': 0, 'has(w)': False, 'count(x)': 0, 'has(x)': False, 'count(y)': 0, 'has(y)': False, 'count(z)': 0, 'has(z)': False}, 'female')]

# %%
#featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
#train_set, devtest_set, test_set = featuresets[1500:], featuresets[500:1500], featuresets[:500]

train_set = apply_features(gender_features2, train_names)
devtest_set = apply_features(gender_features2, devtest_names)
test_set = apply_features(gender_features2, test_names)

print(type(train_set))
print()
print(train_set[:3])
print()

classifier = nltk.NaiveBayesClassifier.train(train_set)
print(classifier)
# Out:
# <class 'nltk.collections.LazyMap'>
#
# [({'first_letter': 'b', 'suffix1': 'e', 'suffix2': 'ee', 'len': 6, 'count(a)': 1, 'has(a)': True, 'count(b)': 2, 'has(b)': True, 'count(c)': 0, 'has(c)': False, 'count(d)': 0, 'has(d)': False, 'count(e)': 2, 'has(e)': True, 'count(f)': 0, 'has(f)': False, 'count(g)': 0, 'has(g)': False, 'count(h)': 0, 'has(h)': False, 'count(i)': 0, 'has(i)': False, 'count(j)': 0, 'has(j)': False, 'count(k)': 0, 'has(k)': False, 'count(l)': 0, 'has(l)': False, 'count(m)': 0, 'has(m)': False, 'count(n)': 0, 'has(n)': False, 'count(o)': 0, 'has(o)': False, 'count(p)': 0, 'has(p)': False, 'count(q)': 0, 'has(q)': False, 'count(r)': 1, 'has(r)': True, 'count(s)': 0, 'has(s)': False, 'count(t)': 0, 'has(t)': False, 'count(u)': 0, 'has(u)': False, 'count(v)': 0, 'has(v)': False, 'count(w)': 0, 'has(w)': False, 'count(x)': 0, 'has(x)': False, 'count(y)': 0, 'has(y)': False, 'count(z)': 0, 'has(z)': False}, 'female'), ({'first_letter': 'j', 'suffix1': 'a', 'suffix2': 'ia', 'len': 5, 'count(a)': 1, 'has(a)': True, 'count(b)': 0, 'has(b)': False, 'count(c)': 0, 'has(c)': False, 'count(d)': 0, 'has(d)': False, 'count(e)': 0, 'has(e)': False, 'count(f)': 0, 'has(f)': False, 'count(g)': 0, 'has(g)': False, 'count(h)': 0, 'has(h)': False, 'count(i)': 1, 'has(i)': True, 'count(j)': 1, 'has(j)': True, 'count(k)': 0, 'has(k)': False, 'count(l)': 1, 'has(l)': True, 'count(m)': 0, 'has(m)': False, 'count(n)': 0, 'has(n)': False, 'count(o)': 0, 'has(o)': False, 'count(p)': 0, 'has(p)': False, 'count(q)': 0, 'has(q)': False, 'count(r)': 0, 'has(r)': False, 'count(s)': 0, 'has(s)': False, 'count(t)': 0, 'has(t)': False, 'count(u)': 1, 'has(u)': True, 'count(v)': 0, 'has(v)': False, 'count(w)': 0, 'has(w)': False, 'count(x)': 0, 'has(x)': False, 'count(y)': 0, 'has(y)': False, 'count(z)': 0, 'has(z)': False}, 'female'), ...]
#
# <nltk.classify.naivebayes.NaiveBayesClassifier object at 0x0000018A5FD4FAC0>

# %%
print(nltk.classify.accuracy(classifier, devtest_set))
classifier.show_most_informative_features(10)
# Out:
# 0.786
# Most Informative Features
#                  suffix2 = 'na'           female : male   =    148.2 : 1.0
#                  suffix2 = 'la'           female : male   =     68.3 : 1.0
#                  suffix2 = 'ia'           female : male   =     49.0 : 1.0
#                  suffix1 = 'k'              male : female =     39.9 : 1.0
#                  suffix2 = 'rd'             male : female =     39.1 : 1.0
#                  suffix1 = 'a'            female : male   =     38.3 : 1.0
#                  suffix2 = 'ta'           female : male   =     27.4 : 1.0
#                  suffix2 = 'us'             male : female =     23.7 : 1.0
#                  suffix2 = 'ch'             male : female =     23.6 : 1.0
#                  suffix2 = 'do'             male : female =     23.6 : 1.0

# %%
errors = []
for (name, tag) in devtest_names:
    guess = classifier.classify(gender_features(name))
    if guess != tag:
        errors.append((tag, guess, name))

for (tag, guess, name) in sorted(errors):
    print('correct={:<8} guess={:<8s} name={:<30}'.format(tag, guess, name))
# Out:
# correct=male     guess=female   name=Abner
# correct=male     guess=female   name=Adrien
# correct=male     guess=female   name=Ahmet
# correct=male     guess=female   name=Al
# correct=male     guess=female   name=Albatros
# correct=male     guess=female   name=Aldus
# correct=male     guess=female   name=Alejandro
# correct=male     guess=female   name=Alfonzo
# correct=male     guess=female   name=Alfred
# correct=male     guess=female   name=Alister
# correct=male     guess=female   name=Alston
# correct=male     guess=female   name=Amadeus
# correct=male     guess=female   name=Amery
# correct=male     guess=female   name=Anders
# correct=male     guess=female   name=Andonis
# correct=male     guess=female   name=Angelico
# correct=male     guess=female   name=Ansel
# correct=male     guess=female   name=Anson
# correct=male     guess=female   name=Antin
# correct=male     guess=female   name=Archie
# correct=male     guess=female   name=Archon
# correct=male     guess=female   name=Arie
# correct=male     guess=female   name=Arnie
# correct=male     guess=female   name=Art
# correct=male     guess=female   name=Ashton
# correct=male     guess=female   name=Averil
# correct=male     guess=female   name=Avram
# correct=male     guess=female   name=Bailey
# correct=male     guess=female   name=Baily
# correct=male     guess=female   name=Bartholomeus
# correct=male     guess=female   name=Bartlet
# correct=male     guess=female   name=Bay
# correct=male     guess=female   name=Bengt
# correct=male     guess=female   name=Berkley
# correct=male     guess=female   name=Bernie
# correct=male     guess=female   name=Bert
# correct=male     guess=female   name=Bertie
# correct=male     guess=female   name=Billie
# correct=male     guess=female   name=Bogart
# correct=male     guess=female   name=Bogdan
# correct=male     guess=female   name=Broddie
# correct=male     guess=female   name=Broderick
# correct=male     guess=female   name=Bronson
# correct=male     guess=female   name=Brooke
# correct=male     guess=female   name=Bruce
# correct=male     guess=female   name=Buddy
# correct=male     guess=female   name=Caleb
# correct=male     guess=female   name=Carroll
# correct=male     guess=female   name=Caryl
# correct=male     guess=female   name=Chance
# correct=male     guess=female   name=Charlie
# correct=male     guess=female   name=Chase
# correct=male     guess=female   name=Christos
# correct=male     guess=female   name=Clay
# correct=male     guess=female   name=Clayborn
# correct=male     guess=female   name=Clem
# correct=male     guess=female   name=Clemente
# correct=male     guess=female   name=Clifford
# correct=male     guess=female   name=Cole
# correct=male     guess=female   name=Coleman
# correct=male     guess=female   name=Connor
# correct=male     guess=female   name=Cooper
# correct=male     guess=female   name=Cortese
# correct=male     guess=female   name=Courtney
# correct=male     guess=female   name=Cris
# correct=male     guess=female   name=Damon
# correct=male     guess=female   name=Dan
# correct=male     guess=female   name=Dani
# correct=male     guess=female   name=Darien
# correct=male     guess=female   name=Davide
# correct=male     guess=female   name=Davon
# correct=male     guess=female   name=Dell
# correct=male     guess=female   name=Demetri
# correct=male     guess=female   name=Demetris
# correct=male     guess=female   name=Demosthenis
# correct=male     guess=female   name=Derrin
# correct=male     guess=female   name=Dewitt
# correct=male     guess=female   name=Dickey
# correct=male     guess=female   name=Dieter
# correct=male     guess=female   name=Dimitrios
# correct=male     guess=female   name=Dimitrou
# correct=male     guess=female   name=Dimitry
# correct=male     guess=female   name=Dom
# correct=male     guess=female   name=Doug
# correct=male     guess=female   name=Duffy
# correct=male     guess=female   name=Earle
# correct=male     guess=female   name=Efram
# correct=male     guess=female   name=Elden
# correct=male     guess=female   name=Eli
# correct=male     guess=female   name=Elijah
# correct=male     guess=female   name=Emmit
# correct=male     guess=female   name=Emory
# correct=male     guess=female   name=Engelbert
# correct=male     guess=female   name=Erasmus
# correct=male     guess=female   name=Ethan
# correct=male     guess=female   name=Ethelred
# correct=male     guess=female   name=Etienne
# correct=male     guess=female   name=Eugene
# correct=male     guess=female   name=Eustace
# correct=male     guess=female   name=Everard
# correct=male     guess=female   name=Federico
# correct=male     guess=female   name=Felicio
# correct=male     guess=female   name=Fernando
# correct=male     guess=female   name=Fletcher
# correct=male     guess=female   name=Forbes
# correct=male     guess=female   name=Forest
# correct=male     guess=female   name=Forester
# correct=male     guess=female   name=Francois
# correct=male     guess=female   name=Freddy
# correct=male     guess=female   name=Fredrick
# correct=male     guess=female   name=Gabriele
# correct=male     guess=female   name=Garret
# correct=male     guess=female   name=Gary
# correct=male     guess=female   name=Gav
# correct=male     guess=female   name=Gavin
# correct=male     guess=female   name=Gearard
# correct=male     guess=female   name=Germaine
# correct=male     guess=female   name=Giancarlo
# correct=male     guess=female   name=Gibb
# correct=male     guess=female   name=Giff
# correct=male     guess=female   name=Gilles
# correct=male     guess=female   name=Giorgio
# correct=male     guess=female   name=Giovanni
# correct=male     guess=female   name=Goddart
# correct=male     guess=female   name=Goose
# correct=male     guess=female   name=Gordan
# correct=male     guess=female   name=Gordon
# correct=male     guess=female   name=Grover
# correct=male     guess=female   name=Hagan
# correct=male     guess=female   name=Hailey
# correct=male     guess=female   name=Hamil
# correct=male     guess=female   name=Hamlet
# correct=male     guess=female   name=Hank
# correct=male     guess=female   name=Hansel
# correct=male     guess=female   name=Hanson
# correct=male     guess=female   name=Harold
# correct=male     guess=female   name=Harry
# correct=male     guess=female   name=Harvie
# correct=male     guess=female   name=Hastings
# correct=male     guess=female   name=Herschel
# correct=male     guess=female   name=Hervey
# correct=male     guess=female   name=Hewet
# correct=male     guess=female   name=Hewitt
# correct=male     guess=female   name=Hezekiah
# correct=male     guess=female   name=Hilary
# correct=male     guess=female   name=Holly
# correct=male     guess=female   name=Horst
# correct=male     guess=female   name=Hunt
# correct=male     guess=female   name=Husein
# correct=male     guess=female   name=Immanuel
# correct=male     guess=female   name=Isidore
# correct=male     guess=female   name=Ismail
# correct=male     guess=female   name=Jackie
# correct=male     guess=female   name=Jacob
# correct=male     guess=female   name=Jacques
# correct=male     guess=female   name=Jamey
# correct=male     guess=female   name=Jed
# correct=male     guess=female   name=Jeffry
# correct=male     guess=female   name=Jens
# correct=male     guess=female   name=Jermain
# correct=male     guess=female   name=Jerri
# correct=male     guess=female   name=Jerrold
# correct=male     guess=female   name=Jessey
# correct=male     guess=female   name=Jeth
# correct=male     guess=female   name=Jim
# correct=male     guess=female   name=Jimmie
# correct=male     guess=female   name=Jock
# correct=male     guess=female   name=Jonah
# correct=male     guess=female   name=Jose
# correct=male     guess=female   name=Joshua
# correct=male     guess=female   name=Josiah
# correct=male     guess=female   name=Juanita
# correct=male     guess=female   name=Judah
# correct=male     guess=female   name=Judith
# correct=male     guess=female   name=Karl
# correct=male     guess=female   name=Keenan
# correct=male     guess=female   name=Keene
# correct=male     guess=female   name=Kendall
# correct=male     guess=female   name=Kennedy
# correct=male     guess=female   name=Kenneth
# correct=male     guess=female   name=Kenyon
# correct=male     guess=female   name=Kevan
# correct=male     guess=female   name=Kin
# correct=male     guess=female   name=Kingsly
# correct=male     guess=female   name=Kip
# correct=male     guess=female   name=Lamont
# correct=male     guess=female   name=Lauren
# correct=male     guess=female   name=Leighton
# correct=male     guess=female   name=Leroy
# correct=male     guess=female   name=Lesley
# correct=male     guess=female   name=Levi
# correct=male     guess=female   name=Lind
# correct=male     guess=female   name=Lindy
# correct=male     guess=female   name=Llewellyn
# correct=male     guess=female   name=Locke
# correct=male     guess=female   name=Lorenzo
# correct=male     guess=female   name=Lucien
# correct=male     guess=female   name=Ludvig
# correct=male     guess=female   name=Luis
# correct=male     guess=female   name=Lyle
# correct=male     guess=female   name=Manny
# correct=male     guess=female   name=Marcelo
# correct=male     guess=female   name=Martainn
# correct=male     guess=female   name=Marten
# correct=male     guess=female   name=Maxie
# correct=male     guess=female   name=Maxwell
# correct=male     guess=female   name=Maynord
# correct=male     guess=female   name=Mayor
# correct=male     guess=female   name=Meredeth
# correct=male     guess=female   name=Merlin
# correct=male     guess=female   name=Merwin
# correct=male     guess=female   name=Michael
# correct=male     guess=female   name=Micheil
# correct=male     guess=female   name=Michel
# correct=male     guess=female   name=Mickey
# correct=male     guess=female   name=Mitchael
# correct=male     guess=female   name=Mohammad
# correct=male     guess=female   name=Munroe
# correct=male     guess=female   name=Murdock
# correct=male     guess=female   name=Mustafa
# correct=male     guess=female   name=Nathan
# correct=male     guess=female   name=Nathaniel
# correct=male     guess=female   name=Nevile
# correct=male     guess=female   name=Nevin
# correct=male     guess=female   name=Niccolo
# correct=male     guess=female   name=Nick
# correct=male     guess=female   name=Nicolas
# correct=male     guess=female   name=Niles
# correct=male     guess=female   name=Noah
# correct=male     guess=female   name=Noland
# correct=male     guess=female   name=Norman
# correct=male     guess=female   name=Oberon
# correct=male     guess=female   name=Oran
# correct=male     guess=female   name=Pablo
# correct=male     guess=female   name=Paddie
# correct=male     guess=female   name=Parsifal
# correct=male     guess=female   name=Partha
# correct=male     guess=female   name=Pat
# correct=male     guess=female   name=Patrick
# correct=male     guess=female   name=Pavel
# correct=male     guess=female   name=Pen
# correct=male     guess=female   name=Pepe
# correct=male     guess=female   name=Petr
# correct=male     guess=female   name=Pincus
# correct=male     guess=female   name=Pip
# correct=male     guess=female   name=Prescott
# correct=male     guess=female   name=Preston
# correct=male     guess=female   name=Puff
# correct=male     guess=female   name=Quinlan
# correct=male     guess=female   name=Rab
# correct=male     guess=female   name=Radcliffe
# correct=male     guess=female   name=Rainer
# correct=male     guess=female   name=Ralph
# correct=male     guess=female   name=Ram
# correct=male     guess=female   name=Raynard
# correct=male     guess=female   name=Raynor
# correct=male     guess=female   name=Reginald
# correct=male     guess=female   name=Reid
# correct=male     guess=female   name=Rem
# correct=male     guess=female   name=Renaud
# correct=male     guess=female   name=Reuben
# correct=male     guess=female   name=Richard
# correct=male     guess=female   name=Richy
# correct=male     guess=female   name=Rickard
# correct=male     guess=female   name=Rob
# correct=male     guess=female   name=Rogers
# correct=male     guess=female   name=Rolland
# correct=male     guess=female   name=Romain
# correct=male     guess=female   name=Rourke
# correct=male     guess=female   name=Royal
# correct=male     guess=female   name=Rudie
# correct=male     guess=female   name=Rudolf
# correct=male     guess=female   name=Ryan
# correct=male     guess=female   name=Salomone
# correct=male     guess=female   name=Sam
# correct=male     guess=female   name=Sammie
# correct=male     guess=female   name=Sander
# correct=male     guess=female   name=Sanford
# correct=male     guess=female   name=Sansone
# correct=male     guess=female   name=Sarge
# correct=male     guess=female   name=Sax
# correct=male     guess=female   name=Sayer
# correct=male     guess=female   name=Sayre
# correct=male     guess=female   name=Scotty
# correct=male     guess=female   name=Sebastiano
# correct=male     guess=female   name=Sergent
# correct=male     guess=female   name=Shanan
# correct=male     guess=female   name=Shannan
# correct=male     guess=female   name=Shelden
# correct=male     guess=female   name=Shlomo
# correct=male     guess=female   name=Shumeet
# correct=male     guess=female   name=Skip
# correct=male     guess=female   name=Skipp
# correct=male     guess=female   name=Skipper
# correct=male     guess=female   name=Skyler
# correct=male     guess=female   name=Stacy
# correct=male     guess=female   name=Stanton
# correct=male     guess=female   name=Stearne
# correct=male     guess=female   name=Steffen
# correct=male     guess=female   name=Stew
# correct=male     guess=female   name=Stuart
# correct=male     guess=female   name=Sully
# correct=male     guess=female   name=Syd
# correct=male     guess=female   name=Taddeus
# correct=male     guess=female   name=Tailor
# correct=male     guess=female   name=Taite
# correct=male     guess=female   name=Talbert
# correct=male     guess=female   name=Tam
# correct=male     guess=female   name=Tedman
# correct=male     guess=female   name=Tedmund
# correct=male     guess=female   name=Teodoor
# correct=male     guess=female   name=Thaddus
# correct=male     guess=female   name=Thadeus
# correct=male     guess=female   name=Theodoric
# correct=male     guess=female   name=Thornie
# correct=male     guess=female   name=Thornton
# correct=male     guess=female   name=Thorpe
# correct=male     guess=female   name=Thorstein
# correct=male     guess=female   name=Tirrell
# correct=male     guess=female   name=Toddy
# correct=male     guess=female   name=Tom
# correct=male     guess=female   name=Tomas
# correct=male     guess=female   name=Tommie
# correct=male     guess=female   name=Torrin
# correct=male     guess=female   name=Torry
# correct=male     guess=female   name=Towny
# correct=male     guess=female   name=Tray
# correct=male     guess=female   name=Tremayne
# correct=male     guess=female   name=Trev
# correct=male     guess=female   name=Tudor
# correct=male     guess=female   name=Tymothy
# correct=male     guess=female   name=Tyrus
# correct=male     guess=female   name=Ulberto
# correct=male     guess=female   name=Ulrich
# correct=male     guess=female   name=Urbanus
# correct=male     guess=female   name=Vassili
# correct=male     guess=female   name=Verge
# correct=male     guess=female   name=Walsh
# correct=male     guess=female   name=Walther
# correct=male     guess=female   name=Ward
# correct=male     guess=female   name=Wat
# correct=male     guess=female   name=Waverly
# correct=male     guess=female   name=Weidar
# correct=male     guess=female   name=Wells
# correct=male     guess=female   name=Westbrooke
# correct=male     guess=female   name=Weylin
# correct=male     guess=female   name=Whitby
# correct=male     guess=female   name=Willis
# correct=male     guess=female   name=Wilmar
# correct=male     guess=female   name=Wilton
# correct=male     guess=female   name=Winnie
# correct=male     guess=female   name=Winslow
# correct=male     guess=female   name=Witold
# correct=male     guess=female   name=Woochang
# correct=male     guess=female   name=Wright
# correct=male     guess=female   name=Wylie
# correct=male     guess=female   name=Wyn
# correct=male     guess=female   name=Xymenes
# correct=male     guess=female   name=Yigal
# correct=male     guess=female   name=Yule
# correct=male     guess=female   name=Yves
# correct=male     guess=female   name=Zack
# correct=male     guess=female   name=Zebadiah
# correct=male     guess=female   name=Zebedee
# correct=male     guess=female   name=Zeke
# correct=male     guess=female   name=Zolly
# correct=male     guess=female   name=Zorro

# %%
test_names = ['Neo', 'Trinity', 'Tommy', 'Tom', 'Mike', 'Michael', 'Barbara', 'Beth', 'Elizabeth', 'Bart', 'Jeremy', 'Isabella', 'Bella', 'Ben', 'Benjamin']
for test_name in test_names:
    print(test_name, classifier.classify(gender_features(test_name)))
# Out:
# Neo female
# Trinity female
# Tommy female
# Tom female
# Mike female
# Michael female
# Barbara female
# Beth female
# Elizabeth female
# Bart female
# Jeremy female
# Isabella female
# Bella female
# Ben female
# Benjamin female
